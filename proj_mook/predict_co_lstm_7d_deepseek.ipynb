# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from scipy import fftpack
import warnings
warnings.filterwarnings('ignore')

# ตั้งค่าสไตล์สำหรับกราฟ
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# โหลดและเตรียมข้อมูล
df = pd.read_csv('CO_hex30_urban.csv')
df['date'] = pd.to_datetime(df['date'])
df.sort_values(['id', 'date'], inplace=True)

print("ข้อมูลของชุดข้อมูล:")
print(f"ช่วงวันที่: {df['date'].min()} ถึง {df['date'].max()}")
print(f"จำนวนเซ็นเซอร์: {df['id'].nunique()}")
print(f"จำนวนข้อมูลทั้งหมด: {len(df)}")

# จัดการค่าที่หายไปโดยใช้การประมาณค่าแบบเฉพาะเจาะจงสำหรับแต่ละเซ็นเซอร์
# แก้ไขข้อผิดพลาดการประมาณค่าแบบใช้เวลา
def interpolate_sensor_data(group):
    # สร้าง DataFrame ชั่วคราวที่มีดัชนี datetime สำหรับการประมาณค่า
    temp_df = group.set_index('date').copy()
    temp_df['CO'] = temp_df['CO'].interpolate(method='time', limit_direction='both')
    temp_df['CO'] = temp_df['CO'].fillna(method='ffill').fillna(method='bfill')
    return temp_df['CO'].values

df['CO'] = df.groupby('id').apply(interpolate_sensor_data).explode().values

# ตรวจสอบว่ายังมีค่า null เหลืออยู่หรือไม่
print(f"ค่าที่หายไปที่เหลืออยู่: {df['CO'].isnull().sum()}")

# รวมค่า CO เฉลี่ยรายวัน
daily_avg = df.groupby('date')['CO'].agg(['mean', 'std', 'min', 'max']).reset_index()
daily_avg.rename(columns={'mean': 'CO'}, inplace=True)

# แสดงสถิติเชิงพรรณนา
print("\nสถิติเชิงพรรณนาสำหรับระดับ CO รายวัน:")
print(daily_avg['CO'].describe())

# 1. Histogram ของค่า CO เฉลี่ยรายวัน
plt.figure(figsize=(10, 6))
plt.hist(daily_avg['CO'], bins=30, edgecolor='black', alpha=0.7)
plt.title('Distribution of Daily Mean CO Values')
plt.xlabel('CO Concentration')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
# plt.savefig('co_histogram.png', dpi=300, bbox_inches='tight')
# plt.close()
plt.show()

# 2. อนุกรมเวลาพร้อมเส้นฐานฟูเรียร์
# สร้างดัชนีเวลา
t = np.arange(len(daily_avg))

# ปรับอนุกรมฟูเรียร์ (ใช้ FFT)
fft = fftpack.fft(daily_avg['CO'].values)
frequencies = fftpack.fftfreq(len(daily_avg))
power = np.abs(fft)

# กรองสัญญาณรบกวนความถี่สูง
fft_filtered = fft.copy()
fft_filtered[np.abs(frequencies) > 0.1] = 0  # ปรับเกณฑ์นี้ตามต้องการ

# สร้างสัญญาณใหม่
co_smooth = np.real(fftpack.ifft(fft_filtered))

plt.figure(figsize=(12, 6))
plt.plot(daily_avg['date'], daily_avg['CO'], label='Actual CO', alpha=0.7)
plt.plot(daily_avg['date'], co_smooth, label='Fourier Baseline', linewidth=2, color='red')
plt.title('CO Time Series with Fourier Baseline')
plt.xlabel('Date')
plt.ylabel('CO Concentration')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)
# plt.savefig('co_time_series_fourier.png', dpi=300, bbox_inches='tight')
# plt.close()
plt.show()

# สร้างลำดับอนุกรมเวลาสำหรับ LSTM
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        seq = data[i:i+n_steps]
        X.append(seq)
        y.append(data[i+n_steps])
    return np.array(X), np.array(y)

n_steps = 14  # ใช้ประวัติ 14 วัน
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(daily_avg[['CO']])

X, y = create_sequences(scaled_data.flatten(), n_steps)

# ปรับรูปร่าง X เป็น 3D สำหรับ LSTM [samples, timesteps, features]
X = X.reshape((X.shape[0], X.shape[1], 1))

# แบ่งข้อมูลฝึกอบรมและทดสอบ (80-20)
split_idx = int(0.8 * len(X))
X_train, X_test = X[:split_idx], X[split_idx:]
y_train, y_test = y[:split_idx], y[split_idx:]

print(f"\nตัวอย่างการฝึกอบรม: {X_train.shape[0]}")
print(f"ตัวอย่างการทดสอบ: {X_test.shape[0]}")

# สร้างโมเดล LSTM ที่ปรับปรุงแล้วด้วยชั้น bidirectional
model = Sequential([
    Bidirectional(LSTM(100, activation='relu', return_sequences=True), input_shape=(n_steps, 1)),
    Dropout(0.3),
    Bidirectional(LSTM(50, activation='relu')),
    Dropout(0.3),
    Dense(25, activation='relu'),
    Dense(1)
])

# กำหนด optimizer พร้อมการกำหนดอัตราการเรียนรู้
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.0001)

# ฝึกโมเดล
print("\nกำลังฝึกโมเดล...")
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=16,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# 4. Learning curve
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.title('Model MAE')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
# plt.savefig('learning_curve.png', dpi=300, bbox_inches='tight')
# plt.close()
plt.show()

# ประเมินโมเดล
y_pred = model.predict(X_test)

# แปลงกลับสู่มาตราส่วนเดิม
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

# คำนวณเมตริก
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)

print("\nเมตริกประสิทธิภาพของโมเดล:")
print(f"RMSE: {rmse:.6f}")
print(f"MAE: {mae:.6f}")
print(f"R²: {r2:.6f}")

# 5. Actual vs Predicted
plt.figure(figsize=(10, 6))
plt.scatter(y_test_inv, y_pred_inv, alpha=0.6)
plt.plot([y_test_inv.min(), y_test_inv.max()], [y_test_inv.min(), y_test_inv.max()], 'r--', lw=2)
plt.xlabel('Actual CO Values')
plt.ylabel('Predicted CO Values')
plt.title(f'Actual vs Predicted CO Values (R² = {r2:.3f})')
plt.grid(True, alpha=0.3)
# plt.savefig('actual_vs_predicted.png', dpi=300, bbox_inches='tight')
# plt.close()
plt.show()

# พยากรณ์ 7 วันถัดไป
last_sequence = scaled_data[-n_steps:].flatten()
forecast = []

for _ in range(7):
    # ปรับรูปร่างสำหรับการพยากรณ์
    seq = last_sequence.reshape(1, n_steps, 1)
    pred = model.predict(seq, verbose=0)
    
    # บันทึกการพยากรณ์
    forecast.append(pred[0, 0])
    
    # อัปเดตลำดับสำหรับการพยากรณ์ครั้งต่อไป
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[-1] = pred[0, 0]

# แปลงกลับสู่มาตราส่วนเดิม
forecast = scaler.inverse_transform(np.array(forecast).reshape(-1, 1))

# สร้างวันที่สำหรับการพยากรณ์
last_date = daily_avg['date'].iloc[-1]
forecast_dates = [last_date + pd.Timedelta(days=i) for i in range(1, 8)]

# 3. พล็อตการพยากรณ์ 7 วัน
plt.figure(figsize=(14, 7))

# ข้อมูลประวัติ
plt.plot(daily_avg['date'], daily_avg['CO'], label='Historical CO', linewidth=2)

# เส้นฐานฟูเรียร์
plt.plot(daily_avg['date'], co_smooth, label='Fourier Baseline', linewidth=2, color='green')

# การพยากรณ์
plt.plot(forecast_dates, forecast, label='7-Day Forecast', linewidth=2, color='red', marker='o')

plt.title('CO Concentration: Historical Data, Fourier Baseline, and 7-Day Forecast')
plt.xlabel('Date')
plt.ylabel('CO Concentration')
plt.legend()
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
# plt.savefig('7_day_forecast.png', dpi=300, bbox_inches='tight')
# plt.close()
plt.show()

# แสดงค่าการพยากรณ์
print("\nการพยากรณ์ 7 วัน:")
forecast_df = pd.DataFrame({
    'Date': forecast_dates,
    'CO_Forecast': forecast.flatten()
})
print(forecast_df.to_string(index=False))

# พิมพ์สรุปโมเดล
print("\nโครงสร้างโมเดล:")
model.summary()

# สร้างสรุปผลลัพธ์แบบครอบคลุม
results_text = f"""
CO PREDICTION MODEL RESULTS
===========================

Dataset Information:
- Date range: {df['date'].min()} to {df['date'].max()}
- Number of sensors: {df['id'].nunique()}
- Total records: {len(df)}
- Remaining null values after processing: {df['CO'].isnull().sum()}

Descriptive Statistics for Daily CO Levels:
{daily_avg['CO'].describe().to_string()}

Model Performance Metrics:
- RMSE: {rmse:.6f}
- MAE: {mae:.6f}
- R²: {r2:.6f}

7-Day Forecast:
{forecast_df.to_string(index=False)}

Model Architecture:
{model.summary()}
"""

# บันทึกผลลัพธ์ไปยังไฟล์
with open('model_results.txt', 'w') as f:
    f.write(results_text)

print("\nการแสดงภาพและผลลัพธ์ทั้งหมดได้ถูกบันทึกไปยังไฟล์:")
print("- co_histogram.png")
print("- co_time_series_fourier.png")
print("- learning_curve.png")
print("- actual_vs_predicted.png")
print("- 7_day_forecast.png")
print("- model_results.txt")

# คำอธิบายขั้นตอนการทำงานในภาษาไทย
procedure_description = """
คำอธิบายขั้นตอนการทำงาน:

1. การเตรียมข้อมูล:
   - โหลดข้อมูลจากไฟล์ CSV และแปลงคอลัมน์วันที่เป็นรูปแบบ datetime
   - เรียงลำดับข้อมูลตาม ID เซ็นเซอร์และวันที่
   - จัดการค่าที่หายไปโดยใช้การประมาณค่าแบบเวลา (time interpolation) สำหรับแต่ละเซ็นเซอร์

2. การวิเคราะห์ข้อมูลเบื้องต้น:
   - คำนวณค่าเฉลี่ยรายวันของระดับ CO
   - สร้างฮิสโตแกรมเพื่อแสดงการกระจายของค่า CO รายวัน
   - ใช้การแปลงฟูเรียร์เพื่อสร้างเส้นฐานสำหรับการวิเคราะห์แนวโน้ม

3. การเตรียมข้อมูลสำหรับแบบจำลอง:
   - สร้างลำดับข้อมูลสำหรับการฝึกแบบจำลอง LSTM
   - ปรับขนาดข้อมูลให้อยู่ในช่วง 0-1 โดยใช้ MinMaxScaler
   - แบ่งข้อมูลเป็นชุดฝึกอบรม (80%) และชุดทดสอบ (20%)

4. การสร้างและฝึกแบบจำลอง:
   - สร้างแบบจำลอง LSTM แบบ bidirectional พร้อม dropout เพื่อป้องกัน overfitting
   - ใช้ early stopping และการปรับอัตราการเรียนรู้แบบลดลงเมื่อเกิดภาวะคงที่
   - ฝึกแบบจำลองด้วยข้อมูลชุดฝึกอบรม

5. การประเมินแบบจำลอง:
   - ทำนายค่าบนชุดทดสอบและคำนวณเมตริกประสิทธิภาพ (RMSE, MAE, R²)
   - สร้างกราฟแสดงความสัมพันธ์ระหว่างค่าจริงและค่าที่ทำนายได้

6. การพยากรณ์:
   - ใช้แบบจำลองที่ฝึกแล้วเพื่อพยากรณ์ระดับ CO สำหรับ 7 วันถัดไป
   - สร้างภาพรวมของการพยากรณ์พร้อมข้อมูลประวัติและเส้นฐานฟูเรียร์

7. การรายงานผล:
   - บันทึกผลลัพธ์ทั้งหมดเป็นไฟล์ภาพและไฟล์ข้อความ
   - สรุปสถิติเชิงพรรณนาและประสิทธิภาพของแบบจำลอง

เทคนิคพิเศษที่ใช้:
- การแปลงฟูเรียร์สำหรับการสร้างเส้นฐานแนวโน้ม
- LSTM แบบ bidirectional สำหรับการจับรูปแบบทั้งจากอดีตไป未來และ未来ไปอดีต
- Dropout และ early stopping เพื่อป้องกัน overfitting
- การปรับอัตราการเรียนรู้แบบลดลงเมื่อเกิดภาวะคงที่

การประยุกต์ใช้:
แบบจำลองนี้สามารถใช้สำหรับการพยากรณ์ระดับมลพิษทางอากาศในเขตเมือง 
และช่วยในการวางแผนจัดการคุณภาพอากาศในอนาคต
"""

# บันทึกคำอธิบายขั้นตอนการทำงาน
with open('procedure_description_th.txt', 'w', encoding='utf-8') as f:
    f.write(procedure_description)

print("คำอธิบายขั้นตอนการทำงานได้ถูกบันทึกไว้ในไฟล์: procedure_description_th.txt")
# Out:
# ข้อมูลของชุดข้อมูล:
# ช่วงวันที่: 2023-11-01 00:00:00 ถึง 2024-04-29 00:00:00
# จำนวนเซ็นเซอร์: 30
# จำนวนข้อมูลทั้งหมด: 5430
# ค่าที่หายไปที่เหลืออยู่: 0
#
# สถิติเชิงพรรณนาสำหรับระดับ CO รายวัน:
# count     181.000000
# unique    181.000000
# top         0.036085
# freq        1.000000
# Name: CO, dtype: float64
# ตัวอย่างการฝึกอบรม: 133
# ตัวอย่างการทดสอบ: 34
#
# กำลังฝึกโมเดล...
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - loss: 0.0386 - mae: 0.1450 - val_loss: 0.0393 - val_mae: 0.1576 - learning_rate: 0.0010
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0186 - mae: 0.1109 - val_loss: 0.0487 - val_mae: 0.1649 - learning_rate: 0.0010
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0174 - mae: 0.0877 - val_loss: 0.0466 - val_mae: 0.1630 - learning_rate: 0.0010
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0146 - mae: 0.0839 - val_loss: 0.0375 - val_mae: 0.1651 - learning_rate: 0.0010
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0145 - mae: 0.0815 - val_loss: 0.0382 - val_mae: 0.1603 - learning_rate: 0.0010
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0138 - mae: 0.0779 - val_loss: 0.0365 - val_mae: 0.1657 - learning_rate: 0.0010
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0133 - mae: 0.0776 - val_loss: 0.0355 - val_mae: 0.1599 - learning_rate: 0.0010
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0126 - mae: 0.0747 - val_loss: 0.0358 - val_mae: 0.1653 - learning_rate: 0.0010
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0129 - mae: 0.0747 - val_loss: 0.0341 - val_mae: 0.1606 - learning_rate: 0.0010
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0110 - mae: 0.0758 - val_loss: 0.0328 - val_mae: 0.1559 - learning_rate: 0.0010
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0136 - mae: 0.0761 - val_loss: 0.0322 - val_mae: 0.1500 - learning_rate: 0.0010
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0120 - mae: 0.0721 - val_loss: 0.0338 - val_mae: 0.1419 - learning_rate: 0.0010
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0132 - mae: 0.0806 - val_loss: 0.0318 - val_mae: 0.1419 - learning_rate: 0.0010
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0141 - mae: 0.0766 - val_loss: 0.0304 - val_mae: 0.1436 - learning_rate: 0.0010
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0142 - mae: 0.0870 - val_loss: 0.0303 - val_mae: 0.1417 - learning_rate: 0.0010
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0112 - mae: 0.0682 - val_loss: 0.0293 - val_mae: 0.1442 - learning_rate: 0.0010
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0129 - mae: 0.0767 - val_loss: 0.0289 - val_mae: 0.1456 - learning_rate: 0.0010
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0125 - mae: 0.0735 - val_loss: 0.0280 - val_mae: 0.1408 - learning_rate: 0.0010
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0110 - mae: 0.0698 - val_loss: 0.0276 - val_mae: 0.1349 - learning_rate: 0.0010
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0114 - mae: 0.0756 - val_loss: 0.0274 - val_mae: 0.1320 - learning_rate: 0.0010
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0122 - mae: 0.0696 - val_loss: 0.0270 - val_mae: 0.1294 - learning_rate: 0.0010
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0118 - mae: 0.0741 - val_loss: 0.0248 - val_mae: 0.1264 - learning_rate: 0.0010
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0110 - mae: 0.0689 - val_loss: 0.0254 - val_mae: 0.1242 - learning_rate: 0.0010
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0122 - mae: 0.0696 - val_loss: 0.0231 - val_mae: 0.1243 - learning_rate: 0.0010
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0100 - mae: 0.0660 - val_loss: 0.0236 - val_mae: 0.1213 - learning_rate: 0.0010
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0101 - mae: 0.0689 - val_loss: 0.0229 - val_mae: 0.1230 - learning_rate: 0.0010
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0105 - mae: 0.0664 - val_loss: 0.0229 - val_mae: 0.1212 - learning_rate: 0.0010
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0111 - mae: 0.0671 - val_loss: 0.0220 - val_mae: 0.1212 - learning_rate: 0.0010
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0095 - mae: 0.0647 - val_loss: 0.0249 - val_mae: 0.1221 - learning_rate: 0.0010
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0113 - mae: 0.0684 - val_loss: 0.0211 - val_mae: 0.1165 - learning_rate: 0.0010
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0097 - mae: 0.0684 - val_loss: 0.0216 - val_mae: 0.1148 - learning_rate: 0.0010
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0117 - mae: 0.0678 - val_loss: 0.0217 - val_mae: 0.1147 - learning_rate: 0.0010
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0115 - mae: 0.0739 - val_loss: 0.0208 - val_mae: 0.1204 - learning_rate: 0.0010
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0095 - mae: 0.0644 - val_loss: 0.0225 - val_mae: 0.1174 - learning_rate: 0.0010
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0102 - mae: 0.0704 - val_loss: 0.0208 - val_mae: 0.1206 - learning_rate: 0.0010
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0097 - mae: 0.0686 - val_loss: 0.0214 - val_mae: 0.1154 - learning_rate: 0.0010
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0092 - mae: 0.0629 - val_loss: 0.0213 - val_mae: 0.1144 - learning_rate: 0.0010
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0096 - mae: 0.0656 - val_loss: 0.0194 - val_mae: 0.1111 - learning_rate: 0.0010
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0112 - mae: 0.0653 - val_loss: 0.0227 - val_mae: 0.1154 - learning_rate: 0.0010
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0097 - mae: 0.0681 - val_loss: 0.0186 - val_mae: 0.1119 - learning_rate: 0.0010
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101 - mae: 0.0658 - val_loss: 0.0219 - val_mae: 0.1142 - learning_rate: 0.0010
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0084 - mae: 0.0601 - val_loss: 0.0171 - val_mae: 0.1082 - learning_rate: 0.0010
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0089 - mae: 0.0708 - val_loss: 0.0179 - val_mae: 0.1066 - learning_rate: 0.0010
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0104 - mae: 0.0625 - val_loss: 0.0195 - val_mae: 0.1086 - learning_rate: 0.0010
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0103 - mae: 0.0669 - val_loss: 0.0164 - val_mae: 0.1062 - learning_rate: 0.0010
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0092 - mae: 0.0588 - val_loss: 0.0183 - val_mae: 0.1074 - learning_rate: 0.0010
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0085 - mae: 0.0624 - val_loss: 0.0170 - val_mae: 0.1082 - learning_rate: 0.0010
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0116 - mae: 0.0713 - val_loss: 0.0188 - val_mae: 0.1098 - learning_rate: 0.0010
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0106 - mae: 0.0645 - val_loss: 0.0212 - val_mae: 0.1125 - learning_rate: 0.0010
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0099 - mae: 0.0707 - val_loss: 0.0197 - val_mae: 0.1107 - learning_rate: 0.0010
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0090 - mae: 0.0640 - val_loss: 0.0200 - val_mae: 0.1114 - learning_rate: 5.0000e-04
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086 - mae: 0.0585 - val_loss: 0.0189 - val_mae: 0.1104 - learning_rate: 5.0000e-04
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0084 - mae: 0.0616 - val_loss: 0.0167 - val_mae: 0.1088 - learning_rate: 5.0000e-04
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0091 - mae: 0.0644 - val_loss: 0.0187 - val_mae: 0.1084 - learning_rate: 5.0000e-04
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0093 - mae: 0.0648 - val_loss: 0.0158 - val_mae: 0.1058 - learning_rate: 5.0000e-04
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0098 - mae: 0.0667 - val_loss: 0.0178 - val_mae: 0.1073 - learning_rate: 5.0000e-04
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0090 - mae: 0.0617 - val_loss: 0.0194 - val_mae: 0.1083 - learning_rate: 5.0000e-04
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0080 - mae: 0.0612 - val_loss: 0.0173 - val_mae: 0.1055 - learning_rate: 5.0000e-04
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0082 - mae: 0.0637 - val_loss: 0.0161 - val_mae: 0.1047 - learning_rate: 5.0000e-04
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0078 - mae: 0.0595 - val_loss: 0.0169 - val_mae: 0.1058 - learning_rate: 5.0000e-04
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0094 - mae: 0.0615 - val_loss: 0.0171 - val_mae: 0.1066 - learning_rate: 2.5000e-04
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0081 - mae: 0.0595 - val_loss: 0.0169 - val_mae: 0.1071 - learning_rate: 2.5000e-04
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086 - mae: 0.0615 - val_loss: 0.0170 - val_mae: 0.1071 - learning_rate: 2.5000e-04
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0084 - mae: 0.0601 - val_loss: 0.0164 - val_mae: 0.1066 - learning_rate: 2.5000e-04
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - mae: 0.0582 - val_loss: 0.0172 - val_mae: 0.1066 - learning_rate: 2.5000e-04
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0076 - mae: 0.0592 - val_loss: 0.0163 - val_mae: 0.1059 - learning_rate: 1.2500e-04
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0087 - mae: 0.0627 - val_loss: 0.0160 - val_mae: 0.1056 - learning_rate: 1.2500e-04
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0081 - mae: 0.0606 - val_loss: 0.0171 - val_mae: 0.1060 - learning_rate: 1.2500e-04
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078 - mae: 0.0575 - val_loss: 0.0177 - val_mae: 0.1058 - learning_rate: 1.2500e-04
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0087 - mae: 0.0596 - val_loss: 0.0173 - val_mae: 0.1057 - learning_rate: 1.2500e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step
#
# เมตริกประสิทธิภาพของโมเดล:
# RMSE: 0.008457
# MAE: 0.007128
# R²: 0.545373
# การพยากรณ์ 7 วัน:
#       Date  CO_Forecast
# 2024-04-30     0.062154
# 2024-05-01     0.063005
# 2024-05-02     0.063812
# 2024-05-03     0.064480
# 2024-05-04     0.065073
# 2024-05-05     0.065646
# 2024-05-06     0.066213
#
# โครงสร้างโมเดล:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_6 (Bidirectional) │ (None, 14, 200)        │        81,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 14, 200)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_7 (Bidirectional) │ (None, 100)            │       100,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 25)             │         2,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 553,655 (2.11 MB)
#  Trainable params: 184,551 (720.90 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 369,104 (1.41 MB)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_6 (Bidirectional) │ (None, 14, 200)        │        81,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 14, 200)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_7 (Bidirectional) │ (None, 100)            │       100,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 25)             │         2,525 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 553,655 (2.11 MB)
#  Trainable params: 184,551 (720.90 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 369,104 (1.41 MB)
# การแสดงภาพและผลลัพธ์ทั้งหมดได้ถูกบันทึกไปยังไฟล์:
# - co_histogram.png
# - co_time_series_fourier.png
# - learning_curve.png
# - actual_vs_predicted.png
# - 7_day_forecast.png
# - model_results.txt
# คำอธิบายขั้นตอนการทำงานได้ถูกบันทึกไว้ในไฟล์: procedure_description_th.txt
